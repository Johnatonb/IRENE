# %%
import keras
import numpy as np
import os
import math
import PIL.Image as Image
import random
from random import shuffle
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from skimage import io
from keras.utils import plot_model
from matplotlib import pyplot as plt
from IPython.display import clear_output
import scipy.io.wavfile
from contextlib import redirect_stdout
import json


def normalize_u8bits(data):
  data = data.astype(float)
  data /= 255.0
  return data


def noising(img):
    gauss = np.random.normal(-100.0,50.0,img.shape)
    noisy = img + gauss
    clipped = np.clip(noisy, 0, 255)
    
    #scratches generator
    for i in range(20000):
        h = random.randint(1, 3)
        w = random.randint(30, 60)
        y = random.randint(0, 80001)
        x = random.randint(0, 205)

        clipped[y-h//2:y+h//2, x-w//2:x+w//2] = 0
        
    #holes generator
    for i in range(4000):
        h = random.randint(5, 10)
        w = random.randint(10, 30)
        y = random.randint(0, 80001)
        x = random.randint(0, 205)

        clipped[y-h//2:y+h//2, x-w//2:x+w//2] = 0
    
    return np.around(clipped).astype(np.uint8)


  
#-----------MAIN----------------
#dir paths
models_dir = '/content/drive/My Drive/models'
results_dir = '/content/drive/My Drive/results'
img_train_dir = "/content/drive/My Drive/dataset_grooves/images/train"
img_ntrain_dir = "/content/drive/My Drive/dataset_grooves/images/noisier_train"
img_test_dir = "/content/drive/My Drive/dataset_grooves/random_grooves/test"
img_ntest_dir = "/content/drive/My Drive/dataset_grooves/random_grooves/noisy_test"
best_results_file = os.path.join(results_dir, 'best_results.txt')



if not os.path.isdir(img_ntrain_dir):
    os.makedirs(img_ntrain_dir)
if not os.path.isdir(img_ntest_dir):
    os.makedirs(img_ntest_dir)
'''
images = os.listdir(img_train_dir)
shuffle(images)
for image_name in images:
    img = io.imread(os.path.join(img_train_dir, image_name) , as_gray=True)
    img = noising(img)
    im = Image.fromarray(img)
    im.save(os.path.join(img_ntrain_dir, image_name))
    #input()
'''
images = os.listdir(img_test_dir)
for image_name in images:
    img = io.imread(os.path.join(img_test_dir, image_name) , as_gray=True)
    img = noising(img)
    im = Image.fromarray(img)
    im.save(os.path.join(img_ntest_dir, image_name))
    #input()
# Out:
# Using TensorFlow backend.

# %%
import keras
import numpy as np
import os
import math
import random
from random import shuffle
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from skimage import io
from keras.utils import plot_model
from matplotlib import pyplot as plt
from IPython.display import clear_output
import scipy.io.wavfile
from contextlib import redirect_stdout
import json


#normalize unsigned 8-bits numpy array to [0;1]
def normalize_u8bits(data):
  data = data.astype(float)
  data /= 255.0
  return data

#normalize signed 16-bits numpy array to [-1;1]
def normalize_16bits(data):
  data = data.astype(float)
  data = (((data+32768)*(2))/65535)-1
  return data

#transform one np array as an array of overlapping smaller arrays of height time_steps
def window_reshape(data, time_steps, predictions):
  reshaped = []
  for i in range(0, data.shape[0]+1-time_steps, predictions):
    reshaped.append(data[i:i+time_steps,:])
  return np.array(reshaped)

#generate a perfect sine wave with amplitude range [-1;1] in a format ready for goal
def generate_sine(freq, size, offset, predictions):
  timestep = 1.0/104000.0
  sine = []
  block = []
  for i in range(size):
    amp = math.cos(2*math.pi*freq*(i+offset)*timestep)
    block.append(amp)
    if (i+1) % predictions == 0:
      sine.append(block)
      block = []
  return np.array(sine)

#plot two metrics and save in result folder
def plot_and_save(metric_val, metric_test, x_max, title, metric_name, time_step_name):
  length = len(metric_train)
  plt.plot(range(x_max), metric_val, label="validation results")
  plt.plot(range(x_max), metric_test, label="test results")
  plt.set_title(title)
  plt.set_ylabel(metric_name)
  plt.set_xlabel(time_step_name)
  plt.legend()
  plt.savefig(os.path.join(result_dir, title+'.png'))
  plt.close()

#create model
def create_model(filter_shapes, 
                 time_steps, 
                 img_width, 
                 activation_function, 
                 max_pool_shape, 
                 dropout_rate, 
                 predictions, 
                 padding,
                 learning_rate,
                 decay,
                 model_dir,
                 model_name):
  model = Sequential()
  model.add(Conv2D(32, filter_shapes[0],
                   input_shape=(time_steps, img_width, 1), padding=padding))
  model.add(Activation(activation_function))
  model.add(Conv2D(32, filter_shapes[1], padding=padding))
  model.add(Activation(activation_function))
  if not max_pool_shape == (1,1):
      model.add(MaxPooling2D(pool_size=max_pool_shape))   
  if not dropout_rate[0]==0.0:
    model.add(Dropout(dropout_rate[0]))
  
  model.add(Conv2D(64, filter_shapes[2], padding=padding))
  model.add(Activation(activation_function))
  model.add(Conv2D(64, filter_shapes[3], padding=padding))
  model.add(Activation(activation_function))
  if not max_pool_shape == (1,1):
      model.add(MaxPooling2D(pool_size=max_pool_shape))
  if not dropout_rate[1]==0.0:
    model.add(Dropout(dropout_rate[1]))

  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation(activation_function))
  if not dropout_rate[2]==0.0:
    model.add(Dropout(dropout_rate[2]))
  model.add(Dense(predictions))
  model.add(Activation('tanh'))
  
  opt = keras.optimizers.Adam(lr=learning_rate, decay=decay)

  model.compile(loss='mean_squared_error',
                optimizer=opt,
                metrics=['mean_absolute_error', 'mean_squared_error'])
            
  with open(os.path.join(model_dir, model_name+'_parameters.txt'), 'w') as f:
    f.write('time_steps_a : '+str(time_steps)+'\n')
    f.write('predictions : ' + str(predictions)+'\n')
    f.write('filter_shapes : '+str(filter_shapes)+'\n')
    f.write('max_pool_shape : '+str(max_pool_shape)+'\n')
    f.write('dropout_rate : '+str(dropout_rate)+'\n')
    f.write('activation : '+activation_function+'\n')
    f.write('padding : '+padding+'\n')
    f.write('learning_rate : '+str(learning_rate)+'\n')
    f.write('decay : '+str(decay)+'\n')
    f.write('optimizer : '+str(opt)+'\n')
  
  model_first_save(model, model_dir, model_name)
  return model
  
def model_first_save(model, model_dir, model_name):
  if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

  plot_model(model, to_file=os.path.join(model_dir, model_name+'_architecture.png'), show_shapes=True, show_layer_names=False)
  with open(os.path.join(model_dir, model_name+'_summary.txt'), 'w') as f:
    with redirect_stdout(f):
        model.summary()

def fit_model(model, images, time_steps, predictions, batch_size, epoch):
  counter=1
  for image_name in images:
    print('image '+str(counter)+'/'+str(len(images)))
    #print('name : '+image_name)
    counter+=1
    img = io.imread(os.path.join(img_train_dir, image_name) , as_gray=True)
    img = noising(img)
    img = img.reshape(img.shape[0], img.shape[1], 1)
    img_norm = normalize_u8bits(img)
    x_train = window_reshape(img_norm, time_steps, predictions)

    freq = int(image_name[1:image_name.find('_')])

    y_train = generate_sine(freq, x_train.shape[0]*predictions, (time_steps//2)-(predictions//2), predictions)

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epoch,
                        initial_epoch=epoch-1,
                        shuffle=True,
                        validation_split=0.15,
                        verbose=1)
  return history
  
def test_model(model, time_steps, predictions):
  testing = os.listdir(img_test_dir)
  i = 0
  glob_scores = []
  for test in testing:
    img_test = io.imread(os.path.join(img_test_dir, test) , as_gray=True)
    #img_test = noising(img_test)
    img_test = img_test.reshape(img_test.shape[0], img_test.shape[1], 1)
    img_test_normalized = normalize_u8bits(img_test)
    x_test = window_reshape(img_test_normalized, time_steps, predictions)

    freq_test = int(test[1:test.find('_')])
    y_test = generate_sine(freq_test, x_test.shape[0]*predictions, (time_steps//2)-(predictions//2), predictions)
    
    scores = model.evaluate(x_test, y_test)
    #print(scores)
    glob_scores.append(scores)
  means = np.mean(glob_scores, axis=0)
  #print(means)
  
  return means


def noising(img):
    gauss = np.random.normal(-100.0,50.0,img.shape)
    noisy = img + gauss
    clipped = np.clip(noisy, 0, 255)
    
    #scratches generator
    for i in range(20000):
        h = random.randint(1, 3)
        w = random.randint(30, 60)
        y = random.randint(0, 80001)
        x = random.randint(0, 205)

        clipped[y-h//2:y+h//2, x-w//2:x+w//2] = 0
        
    #holes generator
    for i in range(4000):
        h = random.randint(5, 10)
        w = random.randint(10, 30)
        y = random.randint(0, 80001)
        x = random.randint(0, 205)

        clipped[y-h//2:y+h//2, x-w//2:x+w//2] = 0
    
    return np.around(clipped).astype(np.uint8)
  
#-----------MAIN----------------
#dir paths
models_dir = '/content/drive/My Drive/models'
results_dir = '/content/drive/My Drive/results'
img_train_dir = "/content/drive/My Drive/dataset_grooves/random_grooves/train"
img_test_dir = "/content/drive/My Drive/dataset_grooves/random_grooves/noisy_test"

model_version_start = 4004 #for output numbering

#network hyper-parameters, default values
epoch_start = 4
epochs = 20
batch_size = 32
time_steps = 15
predictions = 1
filter_shapes = [(3,3),(3,3),(3,3),(3,3)]
img_width = 220
learning_rate = 0.001
decay = 0.0
steps_for_testing = 100 # 1 step = 1 image
max_pool_shape = (2, 2)
dropout_rate = [0.8, 0.7, 0.7]
activation_function = 'relu'
padding='same'
division = 10 # epoch division for testing and saving

current_epoch = 1
current_mv = 0

for epoch in range(epoch_start,epochs+epoch_start):
  
  model_version = model_version_start
  
  images = os.listdir(img_train_dir)
  shuffle(images)
  
  model_name = 'model'+str(model_version)

  print(model_name+', epoch '+str(epoch))
  
  model_dir = os.path.join(models_dir, model_name)
  if not os.path.isdir(model_dir):
    os.makedirs(model_dir)

  #loading model
  if epoch > 1:
    model = load_model(os.path.join(model_dir, model_name+'_epoch'+str(epoch-1)+'.h5'))
  else:

    model = create_model(filter_shapes=filter_shapes,
                        time_steps=time_steps,
                        img_width=img_width,
                        activation_function=activation_function,
                        max_pool_shape=max_pool_shape,
                        dropout_rate=dropout_rate,
                        predictions=predictions,
                        padding=padding,
                        learning_rate = learning_rate,
                        decay = decay,
                        model_dir = model_dir,
                        model_name = model_name)
  size = len(images)//division
  for nth in range(0, division) :
    #fitting model over one epoch
    train_results = fit_model(model, images[nth*size:(nth+1)*size], time_steps, predictions, batch_size, epoch)

    #saving model
    stamp = str(epoch-1)+'.'+str(nth+1) if nth < division-1 else str(epoch)
    model.save(os.path.join(model_dir, model_name+'_epoch'+stamp+'.h5'))

    #testing model
    test_results = test_model(model, time_steps, predictions)

    #appending results
    result_dir = os.path.join(results_dir, model_name)
    if epoch==1 and nth == 0:
      results = {}
      results['mae_validation']={}
      results['mse_validation']={}
      results['mae_test']={}
      results['mse_test']={}
      if not os.path.isdir(result_dir):
        os.makedirs(result_dir)
    else:
      with open(os.path.join(result_dir, model_name+'_results.json'), 'r') as fp:
        results = json.load(fp)

    results['mae_validation'][stamp] = train_results.history['val_mean_absolute_error']
    results['mse_validation'][stamp] = train_results.history['val_mean_squared_error']
    results['mae_test'][stamp] = test_results[1]
    results['mse_test'][stamp] = test_results[0]

    with open(os.path.join(result_dir, model_name+'_results.json'), 'w') as f:
      json.dump(results, f)
# Out:
# Using TensorFlow backend.
# model4004, epoch 4
# WARNING: Logging before flag parsing goes to stderr.
# W0731 07:06:22.961585 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 07:06:23.014743 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 07:06:23.083902 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0731 07:06:23.088231 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 07:06:23.089932 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0731 07:06:23.106691 139777853491072 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 07:06:23.317500 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0731 07:06:26.517340 139777853491072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 71s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0292 - mean_squared_error: 0.0016 - val_loss: 2.3064e-04 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 2.3064e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0014 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 2.3546e-04 - val_mean_absolute_error: 0.0112 - val_mean_squared_error: 2.3546e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 999us/step - loss: 0.0028 - mean_absolute_error: 0.0365 - mean_squared_error: 0.0028 - val_loss: 7.5295e-04 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 7.5295e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 2.4531e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.4531e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0042 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0042 - val_loss: 0.0021 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0021
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0017 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0017 - val_loss: 2.8862e-04 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 2.8862e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 992us/step - loss: 0.0016 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0016 - val_loss: 2.6833e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.6833e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 991us/step - loss: 0.0013 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 4.0620e-04 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 4.0620e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0014 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 3.7324e-04 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 3.7324e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 993us/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 3.3533e-04 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.3533e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0013 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 3.4503e-04 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 3.4503e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 993us/step - loss: 0.0013 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - val_loss: 1.3992e-04 - val_mean_absolute_error: 0.0090 - val_mean_squared_error: 1.3992e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 2.7989e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.7989e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0013 - mean_absolute_error: 0.0261 - mean_squared_error: 0.0013 - val_loss: 2.6549e-04 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 2.6549e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 993us/step - loss: 0.0012 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0012 - val_loss: 2.9384e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.9384e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0013 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 4.2379e-04 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 4.2379e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0015 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 3.4110e-04 - val_mean_absolute_error: 0.0140 - val_mean_squared_error: 3.4110e-04
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 228us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 225us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0013 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 2.1102e-04 - val_mean_absolute_error: 0.0113 - val_mean_squared_error: 2.1102e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0013 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 4.1165e-04 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 4.1165e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0013 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - val_loss: 1.8243e-04 - val_mean_absolute_error: 0.0100 - val_mean_squared_error: 1.8243e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0014 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0014 - val_loss: 2.6365e-04 - val_mean_absolute_error: 0.0115 - val_mean_squared_error: 2.6365e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0015 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0015 - val_loss: 2.3341e-04 - val_mean_absolute_error: 0.0105 - val_mean_squared_error: 2.3341e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0012 - mean_absolute_error: 0.0255 - mean_squared_error: 0.0012 - val_loss: 2.6840e-04 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 2.6840e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0013 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0013 - val_loss: 2.6902e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.6902e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0020 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0020 - val_loss: 3.7761e-04 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.7761e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0016 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0016 - val_loss: 5.5665e-04 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 5.5665e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 996us/step - loss: 0.0017 - mean_absolute_error: 0.0297 - mean_squared_error: 0.0017 - val_loss: 2.6227e-04 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 2.6227e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0012 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 2.2934e-04 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 2.2934e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0018 - mean_absolute_error: 0.0304 - mean_squared_error: 0.0018 - val_loss: 4.0055e-04 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 4.0055e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 990us/step - loss: 0.0013 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 2.3166e-04 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 2.3166e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0015 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0015 - val_loss: 2.6968e-04 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 2.6968e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 992us/step - loss: 0.0012 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0012 - val_loss: 4.0393e-04 - val_mean_absolute_error: 0.0152 - val_mean_squared_error: 4.0393e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 994us/step - loss: 0.0015 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 3.6163e-04 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6163e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 993us/step - loss: 0.0014 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0014 - val_loss: 2.6727e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.6727e-04
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 230us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 229us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 230us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 222us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0013 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 2.4007e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.4007e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 996us/step - loss: 0.0013 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0013 - val_loss: 2.8826e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.8826e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 995us/step - loss: 0.0015 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 3.0647e-04 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 3.0647e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0014 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 2.5611e-04 - val_mean_absolute_error: 0.0117 - val_mean_squared_error: 2.5611e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 995us/step - loss: 0.0027 - mean_absolute_error: 0.0365 - mean_squared_error: 0.0027 - val_loss: 6.5730e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 6.5730e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 1ms/step - loss: 0.0163 - mean_absolute_error: 0.0832 - mean_squared_error: 0.0163 - val_loss: 0.0085 - val_mean_absolute_error: 0.0579 - val_mean_squared_error: 0.0085
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0023 - val_loss: 3.6593e-04 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.6593e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 998us/step - loss: 0.0015 - mean_absolute_error: 0.0284 - mean_squared_error: 0.0015 - val_loss: 3.0540e-04 - val_mean_absolute_error: 0.0118 - val_mean_squared_error: 3.0540e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 995us/step - loss: 0.0018 - mean_absolute_error: 0.0307 - mean_squared_error: 0.0018 - val_loss: 2.9908e-04 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 2.9908e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 992us/step - loss: 0.0023 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0023 - val_loss: 5.9661e-04 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 5.9661e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0016 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0016 - val_loss: 3.2019e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 3.2019e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 990us/step - loss: 0.0018 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0018 - val_loss: 4.2580e-04 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 4.2580e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 992us/step - loss: 0.0021 - mean_absolute_error: 0.0329 - mean_squared_error: 0.0021 - val_loss: 6.6648e-04 - val_mean_absolute_error: 0.0171 - val_mean_squared_error: 6.6648e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0019 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0019 - val_loss: 7.1019e-04 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 7.1019e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 68s 994us/step - loss: 0.0022 - mean_absolute_error: 0.0331 - mean_squared_error: 0.0022 - val_loss: 8.5555e-04 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 8.5555e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0017 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0017 - val_loss: 4.7825e-04 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 4.7825e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0014 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 2.4340e-04 - val_mean_absolute_error: 0.0107 - val_mean_squared_error: 2.4340e-04
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 19s 232us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 19s 231us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0015 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 3.5799e-04 - val_mean_absolute_error: 0.0143 - val_mean_squared_error: 3.5799e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0017 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0017 - val_loss: 3.1256e-04 - val_mean_absolute_error: 0.0129 - val_mean_squared_error: 3.1256e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0014 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 2.1582e-04 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 2.1582e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 2.6692e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.6692e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0013 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 1.7412e-04 - val_mean_absolute_error: 0.0095 - val_mean_squared_error: 1.7412e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0014 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0014 - val_loss: 2.0326e-04 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 2.0326e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 2.0780e-04 - val_mean_absolute_error: 0.0107 - val_mean_squared_error: 2.0780e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0014 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0014 - val_loss: 3.5140e-04 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.5140e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0179 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0179 - val_loss: 0.0084 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0084
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0028 - mean_absolute_error: 0.0379 - mean_squared_error: 0.0028 - val_loss: 5.8210e-04 - val_mean_absolute_error: 0.0158 - val_mean_squared_error: 5.8210e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0020 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0020 - val_loss: 3.0513e-04 - val_mean_absolute_error: 0.0134 - val_mean_squared_error: 3.0513e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0022 - mean_absolute_error: 0.0333 - mean_squared_error: 0.0022 - val_loss: 5.1527e-04 - val_mean_absolute_error: 0.0160 - val_mean_squared_error: 5.1527e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0015 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - val_loss: 2.7524e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.7524e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0015 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0015 - val_loss: 3.0355e-04 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 3.0355e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0013 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0013 - val_loss: 2.6773e-04 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 2.6773e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0014 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 3.4220e-04 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.4220e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0013 - mean_absolute_error: 0.0264 - mean_squared_error: 0.0013 - val_loss: 3.8630e-04 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 3.8630e-04
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 228us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 227us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0013 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 3.1883e-04 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.1883e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0014 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - val_loss: 3.1531e-04 - val_mean_absolute_error: 0.0131 - val_mean_squared_error: 3.1531e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0014 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 3.2886e-04 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.2886e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0034 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0034 - val_loss: 9.7827e-04 - val_mean_absolute_error: 0.0204 - val_mean_squared_error: 9.7827e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0340 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0340 - val_loss: 0.0247 - val_mean_absolute_error: 0.0960 - val_mean_squared_error: 0.0247
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0036 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0036 - val_loss: 8.4282e-04 - val_mean_absolute_error: 0.0185 - val_mean_squared_error: 8.4282e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0019 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0019 - val_loss: 4.1305e-04 - val_mean_absolute_error: 0.0161 - val_mean_squared_error: 4.1305e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0019 - mean_absolute_error: 0.0318 - mean_squared_error: 0.0019 - val_loss: 3.7064e-04 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 3.7064e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0017 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0017 - val_loss: 3.6475e-04 - val_mean_absolute_error: 0.0138 - val_mean_squared_error: 3.6475e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0014 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 2.3987e-04 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 2.3987e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0013 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 2.3076e-04 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 2.3076e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0043 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0043 - val_loss: 0.0012 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0012
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0015 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 2.5538e-04 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 2.5538e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0014 - val_loss: 3.9881e-04 - val_mean_absolute_error: 0.0160 - val_mean_squared_error: 3.9881e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0012 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0012 - val_loss: 1.9821e-04 - val_mean_absolute_error: 0.0108 - val_mean_squared_error: 1.9821e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0013 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0013 - val_loss: 1.8312e-04 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.8312e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0015 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - val_loss: 2.4504e-04 - val_mean_absolute_error: 0.0118 - val_mean_squared_error: 2.4504e-04
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 230us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 224us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0015 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0015 - val_loss: 2.4738e-04 - val_mean_absolute_error: 0.0118 - val_mean_squared_error: 2.4738e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 989us/step - loss: 0.0013 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - val_loss: 4.6149e-04 - val_mean_absolute_error: 0.0160 - val_mean_squared_error: 4.6149e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0019 - mean_absolute_error: 0.0316 - mean_squared_error: 0.0019 - val_loss: 4.7688e-04 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 4.7688e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0015 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0015 - val_loss: 4.2752e-04 - val_mean_absolute_error: 0.0156 - val_mean_squared_error: 4.2752e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0146 - mean_absolute_error: 0.0773 - mean_squared_error: 0.0146 - val_loss: 0.0048 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0048
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0024 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0024 - val_loss: 2.5041e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.5041e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 2.8157e-04 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 2.8157e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0017 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0017 - val_loss: 2.9650e-04 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 2.9650e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0016 - mean_absolute_error: 0.0293 - mean_squared_error: 0.0016 - val_loss: 2.5132e-04 - val_mean_absolute_error: 0.0113 - val_mean_squared_error: 2.5132e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0017 - mean_absolute_error: 0.0302 - mean_squared_error: 0.0017 - val_loss: 3.0525e-04 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 3.0525e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0018 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0018 - val_loss: 6.8625e-04 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 6.8625e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0023 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0023 - val_loss: 4.9580e-04 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 4.9580e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 3.0674e-04 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 3.0674e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0030 - mean_absolute_error: 0.0377 - mean_squared_error: 0.0030 - val_loss: 8.9121e-04 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 8.9121e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0018 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0018 - val_loss: 4.8927e-04 - val_mean_absolute_error: 0.0156 - val_mean_squared_error: 4.8927e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0057 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0057 - val_loss: 0.0028 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0028
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 981us/step - loss: 0.0019 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0019 - val_loss: 3.8596e-04 - val_mean_absolute_error: 0.0148 - val_mean_squared_error: 3.8596e-04
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 229us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 221us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 229us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0015 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 2.7672e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.7672e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0124 - mean_absolute_error: 0.0730 - mean_squared_error: 0.0124 - val_loss: 0.0064 - val_mean_absolute_error: 0.0506 - val_mean_squared_error: 0.0064
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0028 - mean_absolute_error: 0.0371 - mean_squared_error: 0.0028 - val_loss: 4.0238e-04 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 4.0238e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0015 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 2.4681e-04 - val_mean_absolute_error: 0.0118 - val_mean_squared_error: 2.4681e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0014 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 2.6230e-04 - val_mean_absolute_error: 0.0117 - val_mean_squared_error: 2.6230e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0015 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0015 - val_loss: 2.9412e-04 - val_mean_absolute_error: 0.0127 - val_mean_squared_error: 2.9412e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0019 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0019 - val_loss: 5.3458e-04 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 5.3458e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0015 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 2.4755e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.4755e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0015 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0015 - val_loss: 4.0556e-04 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 4.0556e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0016 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0016 - val_loss: 3.8353e-04 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.8353e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0019 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0019 - val_loss: 3.8703e-04 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 3.8703e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0015 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0015 - val_loss: 3.6376e-04 - val_mean_absolute_error: 0.0145 - val_mean_squared_error: 3.6376e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0014 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0014 - val_loss: 4.6881e-04 - val_mean_absolute_error: 0.0156 - val_mean_squared_error: 4.6881e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# ...
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 222us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0015 - mean_absolute_error: 0.0280 - mean_squared_error: 0.0015 - val_loss: 2.0775e-04 - val_mean_absolute_error: 0.0106 - val_mean_squared_error: 2.0775e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0022 - mean_absolute_error: 0.0336 - mean_squared_error: 0.0022 - val_loss: 6.4624e-04 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 6.4624e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0016 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0016 - val_loss: 2.5775e-04 - val_mean_absolute_error: 0.0124 - val_mean_squared_error: 2.5775e-04
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 3.2624e-04 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.2624e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0013 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0013 - val_loss: 2.6626e-04 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 2.6626e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0014 - val_loss: 2.1927e-04 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 2.1927e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0683 - mean_absolute_error: 0.1602 - mean_squared_error: 0.0683 - val_loss: 0.0346 - val_mean_absolute_error: 0.1156 - val_mean_squared_error: 0.0346
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 982us/step - loss: 0.0070 - mean_absolute_error: 0.0596 - mean_squared_error: 0.0070 - val_loss: 8.1712e-04 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 8.1712e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0025 - mean_absolute_error: 0.0362 - mean_squared_error: 0.0025 - val_loss: 4.2323e-04 - val_mean_absolute_error: 0.0152 - val_mean_squared_error: 4.2323e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0019 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0019 - val_loss: 3.2118e-04 - val_mean_absolute_error: 0.0136 - val_mean_squared_error: 3.2118e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0017 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0017 - val_loss: 2.5326e-04 - val_mean_absolute_error: 0.0111 - val_mean_squared_error: 2.5326e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0014 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0014 - val_loss: 2.7728e-04 - val_mean_absolute_error: 0.0123 - val_mean_squared_error: 2.7728e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 987us/step - loss: 0.0026 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0026 - val_loss: 7.5649e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 7.5649e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0015 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0015 - val_loss: 2.7497e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 2.7497e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0017 - mean_absolute_error: 0.0306 - mean_squared_error: 0.0017 - val_loss: 3.6154e-04 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.6154e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 984us/step - loss: 0.0014 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 3.2071e-04 - val_mean_absolute_error: 0.0130 - val_mean_squared_error: 3.2071e-04
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 4/4
# 67988/67988 [==============================] - 67s 983us/step - loss: 0.0023 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0023 - val_loss: 5.7973e-04 - val_mean_absolute_error: 0.0163 - val_mean_squared_error: 5.7973e-04
# 79986/79986 [==============================] - 18s 228us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 230us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# model4004, epoch 5
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 998us/step - loss: 0.0019 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0019 - val_loss: 5.3586e-04 - val_mean_absolute_error: 0.0170 - val_mean_squared_error: 5.3586e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - mean_squared_error: 0.0014 - val_loss: 2.4805e-04 - val_mean_absolute_error: 0.0119 - val_mean_squared_error: 2.4805e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 996us/step - loss: 0.0038 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0038 - val_loss: 0.0017 - val_mean_absolute_error: 0.0288 - val_mean_squared_error: 0.0017
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 1000us/step - loss: 0.0026 - mean_absolute_error: 0.0351 - mean_squared_error: 0.0026 - val_loss: 3.9196e-04 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 3.9196e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 990us/step - loss: 0.0023 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0023 - val_loss: 6.2410e-04 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 6.2410e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0016 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0016 - val_loss: 3.0003e-04 - val_mean_absolute_error: 0.0121 - val_mean_squared_error: 3.0003e-04
# image 7/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 991us/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - val_loss: 3.2309e-04 - val_mean_absolute_error: 0.0133 - val_mean_squared_error: 3.2309e-04
# image 8/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 996us/step - loss: 0.0017 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0017 - val_loss: 4.9273e-04 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 4.9273e-04
# image 9/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 988us/step - loss: 0.0019 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0019 - val_loss: 5.1983e-04 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 5.1983e-04
# image 10/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 997us/step - loss: 0.0015 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0015 - val_loss: 4.0874e-04 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 4.0874e-04
# image 11/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0017 - mean_absolute_error: 0.0305 - mean_squared_error: 0.0017 - val_loss: 5.3293e-04 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 5.3293e-04
# image 12/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 993us/step - loss: 0.0014 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - val_loss: 2.6396e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.6396e-04
# image 13/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 986us/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - val_loss: 2.3130e-04 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 2.3130e-04
# image 14/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 992us/step - loss: 0.0041 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0041 - val_loss: 8.8026e-04 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 8.8026e-04
# image 15/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 990us/step - loss: 0.0023 - mean_absolute_error: 0.0345 - mean_squared_error: 0.0023 - val_loss: 6.5562e-04 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 6.5562e-04
# image 16/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 993us/step - loss: 0.0126 - mean_absolute_error: 0.0733 - mean_squared_error: 0.0126 - val_loss: 0.0059 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0059
# image 17/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 67s 985us/step - loss: 0.0023 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0023 - val_loss: 5.4721e-04 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 5.4721e-04
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 230us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 228us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 226us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 228us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 227us/step
# 79986/79986 [==============================] - 18s 222us/step
# 79986/79986 [==============================] - 18s 223us/step
# 79986/79986 [==============================] - 18s 224us/step
# 79986/79986 [==============================] - 18s 229us/step
# 79986/79986 [==============================] - 18s 225us/step
# 79986/79986 [==============================] - 18s 223us/step
# image 1/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 69s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0023 - val_loss: 2.8885e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.8885e-04
# image 2/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 69s 1ms/step - loss: 0.0031 - mean_absolute_error: 0.0386 - mean_squared_error: 0.0031 - val_loss: 6.3740e-04 - val_mean_absolute_error: 0.0159 - val_mean_squared_error: 6.3740e-04
# image 3/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 69s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0052 - val_loss: 0.0020 - val_mean_absolute_error: 0.0262 - val_mean_squared_error: 0.0020
# image 4/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 69s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0313 - mean_squared_error: 0.0019 - val_loss: 2.6150e-04 - val_mean_absolute_error: 0.0120 - val_mean_squared_error: 2.6150e-04
# image 5/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 67988/67988 [==============================] - 68s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0324 - mean_squared_error: 0.0020 - val_loss: 6.1551e-04 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 6.1551e-04
# image 6/17
# Train on 67988 samples, validate on 11998 samples
# Epoch 5/5
# 16096/67988 [======>.......................] - ETA: 50s - loss: 0.0187 - mean_absolute_error: 0.0892 - mean_squared_error: 0.0187

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
